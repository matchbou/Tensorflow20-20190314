# %% [markdown]
# <a href="https://colab.research.google.com/github/matchbou/Tensorflow20-20190314/blob/master/DataAugumentation20190314aa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://qiita.com/cvusk/items/aa628e84e72cdf0a6e77

# %%
import numpy as np
import random
from PIL import Image
from skimage import transform
from skimage import util

# %%
# show upload dialog
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d79bc3a-4f86-4c83-b045-c74b286621d1" name="files[]" multiple disabled />
#      <output id="result-6d79bc3a-4f86-4c83-b045-c74b286621d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.png to cat.png

# %%
# load image data
img = Image.open("cat.png")
np_img = np.asarray(img)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500 at 0x7FD14E7D59B0>

# %%
# horizontal flip
def horizontal_flip(image):
    return image[:, ::-1, :]
hf_img = horizontal_flip(np_img)
Image.fromarray(hf_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FD14E75C4A8>

# %%
# rotate
def rotate_image(image):
    return transform.rotate(image, angle=random.randint(-15, 15), resize=False, center=None)
rt_img = rotate_image(np_img)
Image.fromarray((rt_img*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FD14E771128>

# %%
# add random noise
noise_img = util.random_noise(np_img)
Image.fromarray((noise_img*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FD14E771400>

# %%
# invert color
inv_img = np.invert(np_img)
Image.fromarray(inv_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FD14E7715F8>
